# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
df = pd.read_csv('Spotify_Youtube.csv')
df.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    Unnamed: 0  Artist  Url_spotify  Track  Album  Album_type    Uri  \
# 0       False   False        False  False  False       False  False
# 1       False   False        False  False  False       False  False
# 2       False   False        False  False  False       False  False
# 3       False   False        False  False  False       False  False
# 4       False   False        False  False  False       False  False
#
#    Danceability  Energy    Key  ...  Url_youtube  Title  Channel  Views  \
# 0         False   False  False  ...        False  False    False  False
# 1         False   False  False  ...        False  False    False  False
# 2         False   False  False  ...        False  False    False  False
# 3         False   False  False  ...        False  False    False  False
# 4         False   False  False  ...        False  False    False  False
#
#    Likes  Comments  Description  Licensed  official_video  Stream
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  Danceability        Energy           Key      Loudness  \
# count  20718.000000  20716.000000  20716.000000  20716.000000  20716.000000
# mean   10358.500000      0.619777      0.635250      5.300348     -7.671680
# std     5980.915774      0.165272      0.214147      3.576449      4.632749
# min        0.000000      0.000000      0.000020      0.000000    -46.251000
# 25%     5179.250000      0.518000      0.507000      2.000000     -8.858000
# 50%    10358.500000      0.637000      0.666000      5.000000     -6.536000
# 75%    15537.750000      0.740250      0.798000      8.000000     -4.931000
# max    20717.000000      0.975000      1.000000     11.000000      0.920000
#
#         Speechiness  Acousticness  Instrumentalness      Liveness  \
# count  20716.000000  20716.000000      20716.000000  20716.000000
# mean       0.096456      0.291535          0.055962      0.193521
# std        0.111960      0.286299          0.193262      0.168531
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Unnamed: 0
# False    20718
# Name: Unnamed: 0, dtype: int64
#
# Artist
# False    20718
# Name: Artist, dtype: int64
#
# Url_spotify
# False    20718
# Name: Url_spotify, dtype: int64
#
# Track
# False    20718
# Name: Track, dtype: int64
#
# Album
# False    20718
# Name: Album, dtype: int64
#
# Album_type
# False    20718
# Name: Album_type, dtype: int64
#
# Uri
# False    20718
# Name: Uri, dtype: int64
#
# Danceability
# False    20716
# True         2
# Name: Danceability, dtype: int64
#
# Energy
# False    20716
# True         2
# Name: Energy, dtype: int64
#
# Key
# False    20716
# True         2
# Name: Key, dtype: int64
#
# Loudness
# False    20716
# True         2
# Name: Loudness, dtype: int64
#
# Speechiness
# False    20716
# True         2
# Name: Speechiness, dtype: int64
#
# Acousticness
# False    20716
# True         2
# Name: Acousticness, dtype: int64
#
# Instrumentalness
# False    20716
# True         2
# Name: Instrumentalness, dtype: int64
#
# Liveness
# ...

# %%
for col in ['Artist', 'Url_spotify', 'Track', 'Album','Album_type','Uri','Url_youtube','Title','Channel','Description','Licensed','official_video']:
    df[col] = df[col].astype('category')

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Artist              category
# Url_spotify         category
# Track               category
# Album               category
# Album_type          category
# Uri                 category
# Danceability         float64
# Energy               float64
# Key                  float64
# Loudness             float64
# Speechiness          float64
# Acousticness         float64
# Instrumentalness     float64
# Liveness             float64
# Valence              float64
# Tempo                float64
# Duration_ms          float64
# Url_youtube         category
# Title               category
# Channel             category
# Views                float64
# Likes                float64
# Comments             float64
# Description         category
# Licensed            category
# official_video      category
# Stream               float64
# dtype: object

# %%
df.fillna(df.mean())
# Out:
# C:\Users\megha\AppData\Local\Temp/ipykernel_4124/634187881.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())
#        Unnamed: 0       Artist  \
# 0               0     Gorillaz
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...

# %%
df['Danceability'].fillna(df['Danceability'].mean(), inplace=True)
df['Energy'].fillna(df['Energy'].mean(), inplace=True)
df['Key'].fillna(df['Key'].mean(), inplace=True)
df['Loudness'].fillna(df['Loudness'].mean(), inplace=True)
df['Speechiness'].fillna(df['Speechiness'].mean(), inplace=True)
df['Acousticness'].fillna(df['Acousticness'].mean(), inplace=True)
df['Instrumentalness'].fillna(df['Instrumentalness'].mean(), inplace=True)
df['Liveness'].fillna(df['Liveness'].mean(), inplace=True)
df['Valence'].fillna(df['Valence'].mean(), inplace=True)
df['Tempo'].fillna(df['Tempo'].mean(), inplace=True)
df['Duration_ms'].fillna(df['Duration_ms'].mean(), inplace=True)
df['Views'].fillna(df['Views'].mean(), inplace=True)
df['Likes'].fillna(df['Likes'].mean(), inplace=True)
df['Comments'].fillna(df['Comments'].mean(), inplace=True)
df['Stream'].fillna(df['Stream'].mean(), inplace=True)

# %%
import numpy as np
df.replace(np.nan,'unknown')
# Out:
#        Unnamed: 0       Artist  \
# 0               0     Gorillaz
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# ...

# %%
# Replace NaN values with the previous category using forward fill
df['Url_youtube'].fillna(method='ffill', inplace=True)
df['official_video'].fillna(method='ffill', inplace=True)
df['Licensed'].fillna(method='ffill', inplace=True)
df['Description'].fillna(method='ffill', inplace=True)
df['Channel'].fillna(method='ffill', inplace=True)
df['Title'].fillna(method='ffill', inplace=True)

# %%
df.loc[412,'Channel']
# Out:
# 'OmarMontesVEVO'

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# Artist              0
# Url_spotify         0
# Track               0
# Album               0
# Album_type          0
# Uri                 0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Url_youtube         0
# Title               0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Description         0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
# saving the dataframe
df.to_excel('YT_Spotify.xls')
#df.to_excel('YT_Spotify.xlsx', index=False)
# Out:
# C:\Users\megha\AppData\Local\Temp/ipykernel_4124/514775109.py:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('YT_Spotify.xls')
